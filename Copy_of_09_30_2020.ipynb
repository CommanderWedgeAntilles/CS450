# %% [markdown]
# <a href="https://colab.research.google.com/github/CommanderWedgeAntilles/CS450/blob/master/Copy_of_09_30_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Encoding

# %%
import pandas as pd

titanic = pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
#do encoding (faster than map)
titanic['Sex_Encoded'] = titanic['Sex'].factorize()[0]
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  Sex_Encoded
# 0            1         0       3  ...   NaN        S            0
# 1            2         1       1  ...   C85        C            1
# 2            3         1       3  ...   NaN        S            1
# 3            4         1       1  ...  C123        S            1
# 4            5         0       3  ...   NaN        S            0
#
# [5 rows x 13 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

#OrdinalEncoder can't deal with missing values, so we have to drop them first
titanic_clean = titanic.dropna().reset_index()

oe = OrdinalEncoder()
transformed = oe.fit_transform(titanic_clean[ ['Sex', 'Embarked'] ])
merged = pd.concat( [titanic_clean, pd.DataFrame(transformed, columns=['Sex_Encoded', 'Embarked_Encoded2'])], axis = 1)
merged.head()
# Out:
#    index  PassengerId  Survived  ... Sex_Encoded Sex_Encoded Embarked_Encoded2
# 0      1            2         1  ...           1         0.0               0.0
# 1      3            4         1  ...           1         0.0               2.0
# 2      6            7         0  ...           0         1.0               2.0
# 3     10           11         1  ...           1         0.0               2.0
# 4     11           12         1  ...           1         0.0               2.0
#
# [5 rows x 16 columns]

# %%
#some algorithms will give 0 and 2 more weight, so we should use dummy variables
titanic_encoded = pd.get_dummies(titanic, columns = ['Sex', 'Pclass'], drop_first=True) #drop_first = True - drops the first columns
titanic_encoded.head()

#OneHotEncoding
# Out:
#    PassengerId  Survived  ... Pclass_2  Pclass_3
# 0            1         0  ...        0         1
# 1            2         1  ...        0         0
# 2            3         1  ...        0         1
# 3            4         1  ...        0         0
# 4            5         0  ...        0         1
#
# [5 rows x 14 columns]

# %%
from sklearn.preprocessing import OneHotEncoder #creates floats

oe = OneHotEncoder(sparse=False)
oe.fit(titanic [ ['Sex'] ])
transformed = oe.transform(titanic[ ['Sex'] ])
x = pd.DataFrame(transformed, columns=['is_female', 'is_male'])

titanic_encoded = pd.concat( [titanic, x], axis = 1)
titanic_encoded.head()
# Out:
#    PassengerId  Survived  Pclass  ... Sex_Encoded is_female  is_male
# 0            1         0       3  ...           0       0.0      1.0
# 1            2         1       1  ...           1       1.0      0.0
# 2            3         1       3  ...           1       1.0      0.0
# 3            4         1       1  ...           1       1.0      0.0
# 4            5         0       3  ...           0       0.0      1.0
#
# [5 rows x 15 columns]

# %% [markdown]
# # Clustering

# %%
cereal = pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/cereal.csv')
cereal.head()
# Out:
#                         name mfr type  calories  ...  shelf  weight  cups     rating
# 0                  100% Bran   N    C        70  ...      3     1.0  0.33  68.402973
# 1          100% Natural Bran   Q    C       120  ...      3     1.0  1.00  33.983679
# 2                   All-Bran   K    C        70  ...      3     1.0  0.33  59.425505
# 3  All-Bran with Extra Fiber   K    C        50  ...      3     1.0  0.50  93.704912
# 4             Almond Delight   R    C       110  ...      3     1.0  0.75  34.384843
#
# [5 rows x 16 columns]

# %%
#K-Means clustering
import altair as alt

alt.Chart(cereal).mark_circle().encode(
    x='calories',
    y='fat',
    tooltip=['name','calories','fat']
)
# Out:
# alt.Chart(...)

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters=3)

km.fit(cereal[['calories','fat']])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
cereal['cluster_id'] = km.labels_
cereal.head()
# Out:
#                         name mfr type  ...  cups     rating  cluster_id
# 0                  100% Bran   N    C  ...  0.33  68.402973           1
# 1          100% Natural Bran   Q    C  ...  1.00  33.983679           0
# 2                   All-Bran   K    C  ...  0.33  59.425505           1
# 3  All-Bran with Extra Fiber   K    C  ...  0.50  93.704912           1
# 4             Almond Delight   R    C  ...  0.75  34.384843           0
#
# [5 rows x 17 columns]

# %%
alt.Chart(cereal).mark_circle().encode(
    x='calories',
    y='fat',
    tooltip=['name','calories','fat'],
    color='cluster_id:N'
)
# Out:
# alt.Chart(...)

# %%
#Need to scale the axeses 
from sklearn.preprocessing import MinMaxScaler
n = MinMaxScaler()

cereal['calories_scaled'] = n.fit_transform(cereal[ ['calories'] ])
cereal['fat_scaled'] = n.fit_transform(cereal[ ['fat'] ])
cereal.head()
# Out:
#                         name mfr type  ...  cluster_id  calories_scaled  fat_scaled
# 0                  100% Bran   N    C  ...           1         0.181818         0.2
# 1          100% Natural Bran   Q    C  ...           0         0.636364         1.0
# 2                   All-Bran   K    C  ...           1         0.181818         0.2
# 3  All-Bran with Extra Fiber   K    C  ...           1         0.000000         0.0
# 4             Almond Delight   R    C  ...           0         0.545455         0.4
#
# [5 rows x 19 columns]

# %%
km = KMeans(n_clusters=3)

km.fit(cereal[['calories_scaled','fat_scaled']])
cereal['cluster_id_two'] = km.labels_
cereal.head()
# Out:
#                         name mfr  ... fat_scaled  cluster_id_two
# 0                  100% Bran   N  ...        0.2               0
# 1          100% Natural Bran   Q  ...        1.0               2
# 2                   All-Bran   K  ...        0.2               0
# 3  All-Bran with Extra Fiber   K  ...        0.0               0
# 4             Almond Delight   R  ...        0.4               2
#
# [5 rows x 20 columns]

# %%
one = alt.Chart(cereal).mark_circle().encode(
    x='calories',
    y='fat',
    tooltip=['name','calories','fat'],
    color='cluster_id:N'
)

two = alt.Chart(cereal).mark_circle().encode(
    x='calories_scaled',
    y='fat_scaled',
    tooltip=['name','calories','fat'],
    color='cluster_id_two:N'
)

one| two
# Out:
# alt.HConcatChart(...)
